# %% [markdown]
# Build a multi-agent system for automated research and report generation using LlamaIndex.
# https://github.com/run-llama/llama_parse/blob/main/examples/multimodal/multimodal_report_generation_agent.ipynb

# %% [markdown]
# https://magazine.sebastianraschka.com/p/new-llm-pre-training-and-post-training
